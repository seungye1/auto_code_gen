# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
import pandas as pd
import string

torch.manual_seed(1013)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Cleaning
#
# * Spacing for punctuation
# * Split train and test data

# %%
import pandas as pd
df = pd.read_csv("data/codegen.csv")
data_x = df["utterance"]
data_y = df["target"]

from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.2)

Datasets = {
    # [cont, cont, cont, cont]
    "iris" : [("sepal_length", "c"), ("sepal_width", "c"),  ("petal_length", "c"), ("petal_width", "c")],
    # [cont, dis, cont, dis, cont, dis, dis, dis, dis, dis, dis, cont, cont, cont, dis]
    "adult" : [("age", "c"), ("workclass", "d"), ("fnlwgt", "c"), ("education", "d"), ("education_num", "c"),  ("marital_status", "d"), ("occupation", "d"), ("house_serv", "d"), ("relationship", "d"), ("race", "d"), ("sex", "d"), ("capital_gain", "c"), ("capital_loss", "c"), ("hours_per_week", "d"), ("native_country", "d")],
    # [dis, rest are cont]
    "wine" : [("alcohol", "d"), ("malic_acid", "c"), ("ash", "c"), ("alcalinity_of_ash", "c"), ("magnesium", "c"), ("total_phenols", "c"),("flavanoids", "c"), ("nonflavanoid_phenols", "c"), ("proanthocyanins", "c"), ("varor_intensity", "c"), ("hue", "c")],
    # all dis
    "car" : [("buying", "c"), ("maint", "c"), ("comfort", "c"), ("doors", "c"), ("persons", "c"), ("lug_boot", "c"), ("safety", "c")],
    # all cont
    "breast_cancer" : [("radius", "c"), ("texture", "c"), ("perimeter", "c"), ("area", "c"), ("smoothness", "c"), ("compactness", "c"), ("concavity", "c"), ("concave_points", "c"), ("symmetry", "c"), ("fractal_dimension", "c")],
    # [dis, dis, dis, cont, cont, dis, dis, cont, dis]
    "heart_disease" : [("age", "d"), ("sex", "d"), ("cp", "d"), ("trestbps", "c"), ("chol", "c"), ("fbs", "d"), ("restecg", "d"), ("thalach", "c"), ("num", "d")],
    # all con except for the last one (quality)
    "wine_quality" : [("fixed_acidity", "c"), ("volatile_acidity", "c"), ("citric_acid", "c"), ("residual_sugar", "c"), ("chlorides", "c"), ("free_sulfur_dioxide", "c"), ("total_sulfur_dioxide", "c"), ("density", "c"), ("pH", "c"), ("sulphates", "c"), ("alcohol", "c"), ("quality", "d")],
    # [cont, cont, cont, dis, dis]
    "smartphones" : [("triaxial_acceleration", "c"), ("triaxial_angular_velocity", "c"), ("561_feature", "c"), ("label", "d"), ("identifier", "d")], 
    # [dis, dis, dis, dis, cont, cont, cont, cont, cont, cont, cont, cont, cont]
    "forest_fire" : [("x", "d"), ("y", "d"), ("month", "d"), ("day", "d"), ("FFMC", "c"), ("DMC", "c"), ("DC", "c"), ("ISI", "c"), ("temp", "c"), ("RH", "c"), ("wind", "c"), ("rain", "c"), ("area", "c")],
    # [dis, cont, cont, cont, cont, cont, cont, cont]
    "abalone" : [("sex", "d"), ("length", "c"), ("diameter", "c"), ("height", "c"), ("whole_weight", "c"), ("shucked_weight", "c"), ("viscera", "c"), ("shell_weight", "c")],
    # [dis, dis, dis, dis, dis, dis, dis, dis, dis, dis, cont, cont, cont, cont, dis, cont, cont, cont, cont, cont]
    "bank_marketing" : [("age", "d"), ("job", "d"), ("marital", "d"), ("education", "d"), ("default", "d"), ("housing", "d"), ("loan", "d"), ("contact", "d"), ("month", "d"), ("day_of_week", "d"), ("duration", "c"), ("campaign", "c"), ("pdays", "c"), ("previous", "c"), ("poutcome", "d"), ("emp.var.rate", "c"), ("cons.price.idx", "c"), ("cons.conf.idx", "c"), ("euribor3m", "c"), ("nr.employed", "c")]
}

data_cols = list(Datasets.keys())

for list_col in Datasets.values():
    for col in list_col:
        data_cols.append(col[0])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-c2527892894a> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("data/codegen.csv")
#       3 data_x = df["utterance"]
#       4 data_y = df["target"]
#       5
#
# /usr/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /usr/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /usr/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /usr/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /usr/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# OSError: Initializing from file failed

# %% [markdown]
# ## Building Vocabulary
# * Input Vocab: `input_vocab`
# * Output Vocab: `output_vocab`

# %%
from collections import Counter

class Vocabulary():
    END_OF_SENTENCE = '<end>'
    NULL = 'NULL'
    UNKNOWN = 'UNK'
    END_OF_SENTENCE_INDEX = 2
    def __init__(self, i):
        self.tok2ind = {self.NULL: 0, self.UNKNOWN: 1, self.END_OF_SENTENCE: 2}
        self.ind2tok = {0: self.NULL, 1: self.UNKNOWN, 2: self.END_OF_SENTENCE}
        self.i = i
        
    def add(self, token):
        if token not in self.tok2ind:
            index = self.i
            self.tok2ind[token] = index
            self.ind2tok[index] = token     
            self.i += 1
    
    def __len__(self):
        return len(self.tok2ind)
    
    def get_index(self, word):
        if word in self.tok2ind:
            return self.tok2ind[word]
        return self.tok2ind[self.UNKNOWN]
    
    def get_word(self, i):
        return self.ind2tok[i]

    def sentence_to_indices(self, sentence):
        words = [x for x in sentence.split(' ')]
        words.append(self.END_OF_SENTENCE)
        indices = [self.get_index(w) for w in words]
        return indices
    
def is_not_numeric(s):
    try:
        val = float(s)
        return False
    except:
        return True
    
def build_vocab(examples):
    word_counts = Counter()
    for ex in examples:
        words = [w for w in ex.split(' ') if w.strip()]
        word_counts.update(words)
    word_list = [w for w in word_counts if w not in data_cols and is_not_numeric(w)]
    word_vocab = Vocabulary(3)
    for w in word_list:
        word_vocab.add(w)
    return word_vocab

def build_oov(x_exs, input_vocab_words, i):
    word_dict = Vocabulary(i)
    for ex in x_exs:
        words = [w for w in ex.split(' ') if w.strip()]
        
        for w in words:
            if w not in input_vocab_words:
                word_dict.add(w)
    fns = ['mean', 'std', 'maximum', 'minimum', 'ranges', 'summation',
        'std', 'variance', 'quantile', 'corr', 'histogram', 
        'boxplot', 'load', 'describe', 'quantile', 'scatterplot', 'corr', 'lr',
        'predict', 'less', 'equal', 'greater']
    for fn in fns:
        word_dict.add(fn)
    return word_dict

input_vocab = build_vocab(train_x)
output_vocab = build_vocab(train_y)
oov_vocab = build_oov(test_x, input_vocab.tok2ind.keys(), len(output_vocab.tok2ind.keys()))

# %% [markdown]
# ## Process train and test datasets as Examples
#
# * Create Example class for each ex
# * Prepare to load to PyTorch dataloader by making specific Dataset class

# %%
from torch.utils.data import Dataset
from torch.utils.data.sampler import Sampler
import string

class Example():
    def __init__(self, x_str, y_str, input_vocab, output_vocab, oov_vocab):
        self.x_str = x_str
        self.y_str = y_str
        self.x_toks = x_str.split(' ')
        self.y_toks = y_str.split(' ')
        self.input_vocab = input_vocab
        self.output_vocab = output_vocab
        self.oov_vocab = oov_vocab
        self.x_ind = torch.LongTensor(input_vocab.sentence_to_indices(x_str))
        self.y_ind = torch.LongTensor(output_vocab.sentence_to_indices(y_str))
        self.oov_ind_x = torch.LongTensor(oov_vocab.sentence_to_indices(x_str))
        self.oov_ind_y = torch.LongTensor(oov_vocab.sentence_to_indices(y_str))
        
        # 1: batch, row: the y pos, col: the x pos
        self.y_in_x_ind = torch.FloatTensor(([[int(x_tok == y_tok) for x_tok in self.x_toks] for y_tok in self.y_toks]))
        
class StatCodeDataset(Dataset):
    def __init__(self, examples):
        self.examples = examples
        
    def __len__(self):
        return len(self.examples)
    
    def __getitem__(self, index):
        return self.examples[index]
    
train_exs = []
for x, y in zip(train_x, train_y):
    train_exs.append(Example(x, y, input_vocab, output_vocab, oov_vocab))
train_dataset = StatCodeDataset(train_exs)

test_exs = []
for x, y in zip(test_x, test_y):
    test_exs.append(Example(x, y, input_vocab, output_vocab, oov_vocab))
test_dataset = StatCodeDataset(test_exs)

# %% [markdown]
# ## Vectorizing Examples
#
# * Write vectorizing function for PyTorch DataLoader
# * Load data into dataloader

# %%
def vectorize(batch):
    # all vectors size (batch, max_input_len or max_output_len)
    max_input_len = max([ex.x_ind.size(0) for ex in batch])
    max_output_len = max([ex.y_ind.size(0) for ex in batch])
    
    # input & output seq (init = 0)
    # batch number rows, max of word sequence number cols
    x = torch.LongTensor(len(batch), max_input_len).zero_()
    y = torch.LongTensor(len(batch), max_output_len).zero_()
    oov_x = torch.LongTensor(len(batch), max_input_len).zero_()
    oov_y = torch.LongTensor(len(batch), max_output_len).zero_()
    
    # softmax mask for input, masked_select for output
    # batch number rows, max of word seq number cols
    x_mask = torch.ByteTensor(len(batch), max_input_len).fill_(1)
    y_mask = torch.ByteTensor(len(batch), max_output_len).zero_()
    
    # stores the last index of each sequence
    x_lens = torch.LongTensor(len(batch)).zero_()
    
    # y_in_x_index resized to max
    y_in_x_ind = torch.FloatTensor(len(batch), max_output_len, max_input_len).zero_()
    
    for i, ex in enumerate(batch):
        # edit ith row from x & y and fill with x_inds & y_inds
        x[i, :ex.x_ind.size(0)].copy_(ex.x_ind)
        oov_x[i, :ex.x_ind.size(0)].copy_(ex.oov_ind_x)
        y[i, :ex.y_ind.size(0)].copy_(ex.y_ind)
        oov_y[i, :ex.y_ind.size(0)].copy_(ex.oov_ind_y)

        # i*max_input_len for getting last hidden state from 2d tensor 
        # (batch_size*max_len, embedding dim)
        # also has last index of each seq
        x_lens[i] = i*max_input_len + ex.x_ind.size(0)-1

        # mask values to zero for input and to one for output
        x_mask[i, :ex.x_ind.size(0)].fill_(0)
        y_mask[i, :ex.y_ind.size(0)].fill_(1)
        
        # copying 1 or no
        y_in_x_ind[i, :ex.y_in_x_ind.size(0), :ex.y_in_x_ind.size(1)].copy_(ex.y_in_x_ind)
    
    
    return x, x_lens, x_mask, y, y_mask, y_in_x_ind, oov_x, oov_y

train_sampler = torch.utils.data.sampler.RandomSampler(train_dataset)
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=50,
    sampler=train_sampler,
    num_workers=100,
    collate_fn=vectorize
)

test_sampler = torch.utils.data.sampler.SequentialSampler(test_dataset)
test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=10,
    sampler=test_sampler,
    num_workers=1,
    collate_fn=vectorize
)
max_input_len = max([ex.x_ind.size(0) for ex in test_dataset])

# %% [markdown]
# # Building the Model

# %% [markdown]
# ## LSTM
# * stack bi-directional LSTM

# %%
class StackBRNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers=1):
        super(StackBRNN, self).__init__()
        self.num_layers = num_layers
        self.rnns = nn.ModuleList()
        
        # have input_seq and out_seq length of LSTM Stacked
        for i in range(num_layers):
            input_dim = input_dim if i == 0 else hidden_dim * 2
            self.rnns.append(nn.LSTM(input_dim, hidden_dim, bidirectional=True))
            
    def forward(self, x):
        # (seq_len, batch_size, input_dim)
        # use inputs as last hidden_layer output
        x = x.transpose(0, 1)
        outputs = [x] 
        
        for i in range(self.num_layers):
            rnn_input = outputs[-1]
            rnn_output = self.rnns[i](rnn_input)[0]
            outputs.append(rnn_output)
        
        # transpose back to (batch_size, seq_len, 2*hidden_dim aka output dim)
        h_output = outputs[-1]
        h_output = h_output.transpose(0, 1)
        return h_output

# %% [markdown]
# ## Attention Sequence to Sequence Model With Copying

# %%
class AttentionSeq2Seq(nn.Module):
    def __init__(self, embedding_dim, hidden_dim, input_vocab, output_vocab):
        super(AttentionSeq2Seq, self).__init__()
        self.input_vocab = input_vocab
        self.output_vocab = output_vocab
        self.in_vocab_size = len(self.input_vocab)
        self.out_vocab_size = len(self.output_vocab)
        
        self.in_embedding = nn.Embedding(self.in_vocab_size, embedding_dim, padding_idx=0)
        self.out_embedding = nn.Embedding(self.out_vocab_size, embedding_dim, padding_idx=0)
        
        self.encoder = StackBRNN(embedding_dim, hidden_dim)
        self.decoder = nn.LSTMCell(embedding_dim + hidden_dim*2, hidden_dim)
        
        self.enc_to_dec = nn.Linear(hidden_dim*2, hidden_dim)
        self.output_layer = nn.Linear(hidden_dim + hidden_dim*2, self.out_vocab_size)
        
    def encode(self, x):
        # batch_size, seq_len, embedding_dim
        x_emb = self.in_embedding(x)
        # batch_size, seq_len, hidden_dim*2 (bc StackBRNN does hidden_dim*2)
        output = self.encoder(x_emb)
        return output
    
    def decode(self, encoder_outputs, encoder_proj_outputs, x_mask, h_prev):
        # copy scores: (batch_size, seq_len)
        # scores calculated using hidden state 
        # encoder outputs, previous hidden outputs
        # (batch_size, seq_len, hidden_dim) * (batch_size, hidden_dim, 1)
        scores = torch.bmm(encoder_proj_outputs, h_prev[0].unsqueeze(2)).squeeze(2)
        scores.data.masked_fill_(x_mask.data, -float('inf'))
        alpha = F.softmax(scores, dim=1)
        # context at t: (batch_size, CONTEXT_VAL 1, seq_len)
        # (batch_size, 1, seq_len) * (batch_size, seq_len, hidden_dim)
        context_t = torch.bmm(alpha.unsqueeze(1), encoder_outputs).squeeze(1)
        # generate scores (regular RNN)
        # H_PREV: previous layer
        out = self.output_layer(torch.cat([h_prev[0], context_t], 1))
        probs = F.softmax(torch.cat([out, scores], 1), dim=1)
        return probs, context_t
    
model = AttentionSeq2Seq(50, 20, input_vocab, output_vocab)

# %% [markdown]
#  ## Train the model

# %%
def train(ex, model, optim):
    # train mode
    model.train()
    
    x, x_lens, x_mask, y, y_mask, y_in_x_ind, oov_x, oov_y = ex
    x, x_lens, x_mask, y, y_mask, y_in_x_ind = Variable(x), Variable(x_lens), Variable(x_mask), Variable(y), Variable(y_mask), Variable(y_in_x_ind)
# print('x',x,'y', y, 'oovx', oov_x, 'oovy',oov_y)
    # input: batch_size, seq_len
    # output: batch_size, (seq_len, hidden_dim*2)
    encoder_outputs = model.encode(x)
    
    # input: batch_size, (seq_len, hidden_dim*2)
    # output: batch_size, seq_len, hidden_dim
    encoder_proj_outputs = model.enc_to_dec(encoder_outputs)
    
    batch_size = x.size(0)
    seq_len = x.size(1)
    
    # batch_1, seq_1: (hidden_dim, hidden_dim, ...., hidden_dim)
    # batch_n, seq_t
    # view encoder_proj_outputs as one long vector, select last hidden state output
    h_0 = torch.index_select(encoder_proj_outputs.view(batch_size*seq_len, -1), 0, x_lens) # be careful when input sequences have paddings
    c_0 = Variable(torch.zeros(h_0.size(0), h_0.size(1)).zero_())
    hidden = (h_0, c_0)
    prob_y_seq = []
    for i in range(y.size(1)):
        output, context_t = model.decode(encoder_outputs, encoder_proj_outputs, x_mask, hidden)

        # next hidden state using current output location
        # (embedding dim + hidden * 2, hidden)
        y_emb = model.out_embedding(y[:, i])
        hidden = model.decoder(torch.cat([y_emb, context_t], 1), hidden)
        
        # prob @ time i
        # (batch_size, 1)
#         print("output", output)
#         print('y', y[:,i])
        p_y_t = output.gather(1, y[:, i].unsqueeze(1)) # (batch_size, 1)
#         print('y_t', i, p_y_t)        # (batch_size, input_len)
        copy_dist = output[:, model.out_vocab_size:model.out_vocab_size + y_in_x_ind.size(2)]
#         print('dist', copy_dist)
#         print('y_inx', y_in_x_ind[:,i])
        copy_p_y_t = torch.bmm(copy_dist.unsqueeze(1), y_in_x_ind[:, i].unsqueeze(2)).squeeze(2)
#         print('copypyt', copy_p_y_t)
        
        p_y_t = p_y_t + copy_p_y_t
#         print('newo',p_y_t)
        prob_y_seq.append(p_y_t)
    prob_y_seq = torch.cat([_ for _ in prob_y_seq], 1)
    prob_y_seq = torch.masked_select(prob_y_seq, y_mask)
    loss = -torch.sum(torch.log(prob_y_seq))/y.size(0)
    
    optim.zero_grad()
    loss.backward()
    optim.step()
    
    return loss.data[0]

optim = torch.optim.Adam(model.parameters(), lr = 0.001)
n_epochs = 40
for e in range(n_epochs):
    train_loss = 0.0
    for ex in train_loader:
        l = train(ex, model, optim)
        train_loss += l
    print("Epoch = %d | Loss = %.2f" % (e, train_loss))
# Out:
# Epoch = 0 | Loss = 2532.96
# Epoch = 1 | Loss = 1042.88
# Epoch = 2 | Loss = 531.11
# Epoch = 3 | Loss = 304.00
# Epoch = 4 | Loss = 209.07

# %% [markdown]
# ## Test batch

# %%
def test_batch(data_loader, oov_vocab, model, max_len=15):
    model.eval()
    
    num_correct = 0
    num_total = 0
    for ex in data_loader:
        x, x_lens, x_mask, y, y_mask, y_in_x_inds, oov_x, oov_y = ex 
        
        x, x_lens, x_mask = Variable(x), Variable(x_lens), Variable(x_mask)
    
        encoder_outputs = model.encode(x) # (batch_size, seq_len, hidden_dim*2)
        encoder_proj_outputs = model.enc_to_dec(encoder_outputs) # (batch_size, seq_len, hidden_dim)
        
        ###CHANGE: make use of x_lens to index the last hidden states
        batch_size = x.size(0)
        seq_len = x.size(1)
        h_0 = torch.index_select(encoder_proj_outputs.view(batch_size*seq_len,-1),0,x_lens) # be careful when input sequences have paddings
    
        c_0 = Variable(torch.zeros(h_0.size(0), h_0.size(1)).zero_()) 
        hidden = (h_0, c_0)
        
        ###CHANGE: start with empty prediction
        seq = []
        for i in range(max_len):
            #output = model.decode(hidden) 
            
            ###CHANGE: update the decode function, move the code that uses y[:, i] down
            output, context_t = model.decode(encoder_outputs, encoder_proj_outputs, x_mask, hidden) # with attention
        
            sampleLogprobs, it = torch.max(output.data, 1)
            y_t = it.view(-1).long()
            seq.append(y_t)
            
            new_y_t = []
            for j in range(y_t.size(0)):
                if y_t[j] < model.out_vocab_size:
                    w = y_t[j]
                else:
                    w = 1 
                new_y_t.append(w)

            new_y_t = torch.LongTensor(new_y_t)
            
            ###compute the next hidden state using the current output y_t
            y_prev = Variable(new_y_t)
            y_emb = model.out_embedding(y_prev) # y_emb: (batch_size, embedding_dim)
            hidden = model.decoder(torch.cat([y_emb, context_t], 1), hidden) 
            
            #hidden = model.decoder(y_emb, hidden)
        
        pred_y = torch.cat([_.unsqueeze(1) for _ in seq], 1)
        for idx in range(batch_size):
            gold_toks = []
            y_list = y[idx].tolist()
            oov_list = oov_y[idx].tolist()
            print(y_list)
            print(oov_list)
            for k in range(len(y_list)):
                wi = y_list[k]
                if wi != 1 :
                    w = model.output_vocab.get_word(wi)
                else:
                    w = oov_vocab.get_word(oov_list[k])
                gold_toks.append(w)
                if w == "<end>":
                    break
            print("Gold: ", ' '.join(gold_toks))
        
            pred_toks = []
            pred_list = pred_y[idx].tolist()
            oov_x_curr = oov_x[idx].tolist()
            print(oov_x_curr)
            print(pred_list)
            for k in range(len(pred_list)):
                wi = pred_list[k]
                if wi < model.out_vocab_size:
                    w = model.output_vocab.get_word(wi)
                else:

                    w = oov_vocab.get_word(oov_x_curr[wi-model.out_vocab_size])                    
                pred_toks.append(w)
                if w == "<end>":
                    break
            print("Predict: ",' '.join(pred_toks))
        if pred_toks == gold_toks:
            num_correct += 1
        num_total +=1
    print('accuracy', num_correct/num_total)
    
test_batch(test_loader, oov_vocab, model)
# Out:
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 31, 1, 1, 1, 30, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = wine_quality , var1 = sulphates ) <end>
# [1, 1, 1, 30, 1, 31, 2, 0, 0, 0, 0, 0, 0]
# [14, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  minimum ( data = wine_quality , var1 = sulphates ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 33, 1, 1, 1, 32, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = heart_disease , var1 = fbs ) <end>
# [1, 1, 1, 32, 1, 33, 1, 2, 0, 0, 0, 0, 0]
# [19, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  summation ( data = heart_disease , var1 = fbs ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 35, 1, 1, 1, 34, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = forest_fire , var1 = y ) <end>
# [1, 1, 34, 1, 35, 1, 2, 0, 0, 0, 0, 0, 0]
# [14, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  minimum ( data = forest_fire , var1 = y ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 38, 1, 1, 1, 36, 1, 1, 1, 37, 1, 2]
# Gold:  corr ( data = bank_marketing , var1 = nr.employed , var2 = euribor3m ) <end>
# [508, 1, 36, 1, 37, 1, 38, 1, 2, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 36, 9, 2, 8, 6, 34, 9, 2, 8, 6]
# Predict:  corr , , val = bank_marketing ) <end>
# [23, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [517, 1, 1, 1, 51, 1, 1, 1, 39, 1, 1, 1, 40, 1, 2]
# Gold:  equal ( data = breast_cancer , var1 = texture , val = -81.2094904586373 ) <end>
# [1, 1, 1, 1, 39, 1, 1, 1, 40, 1, 2, 0, 0]
# [23, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  equal ( data = UNK , var1 = texture , val = -81.2094904586373 ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 48, 1, 1, 1, 41, 1, 1, 1, 42, 1, 2]
# Gold:  less_eq ( data = adult , var1 = race , val = 20.41325285288478 ) <end>
# [1, 1, 1, 1, 41, 1, 1, 1, 1, 1, 42, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = race , val = 20.41325285288478 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 38, 1, 1, 1, 43, 1, 1, 1, 44, 1, 2]
# Gold:  corr ( data = bank_marketing , var1 = poutcome , var2 = marital ) <end>
# [1, 1, 43, 1, 44, 1, 38, 1, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = bank_marketing , var1 = poutcome , var2 = marital ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 69, 1, 1, 1, 45, 1, 1, 1, 46, 1, 2]
# Gold:  less_eq ( data = smartphones , var1 = triaxial_acceleration , val = 59.7951024073929 ) <end>
# [1, 1, 1, 1, 45, 1, 1, 1, 46, 1, 2, 0, 0]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = triaxial_acceleration , val = 59.7951024073929 ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 48, 1, 1, 1, 47, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = adult , var1 = occupation ) <end>
# [1, 1, 1, 47, 1, 48, 1, 2, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  std ( data = adult , var1 = occupation ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 38, 1, 1, 1, 49, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = bank_marketing , var1 = education ) <end>
# [1, 1, 49, 1, 38, 1, 2, 0, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  ranges ( data = bank_marketing , var1 = education ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 38, 1, 1, 1, 43, 1, 1, 1, 44, 1, 2]
# Gold:  scatterplot ( data = bank_marketing , var1 = poutcome , var2 = marital ) <end>
# [1, 1, 1, 43, 1, 44, 1, 38, 1, 2, 0, 0, 0]
# [15, 4, 5, 6, 37, 7, 8, 6, 33, 7, 13, 6, 35, 9, 2]
# Predict:  scatterplot ( data = bank_marketing , var1 = poutcome , var2 = marital ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 51, 1, 1, 1, 50, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = breast_cancer , var1 = fractal_dimension ) <end>
# [1, 1, 1, 50, 1, 51, 2, 0, 0, 0, 0, 0, 0]
# [19, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  summation ( data = breast_cancer , var1 = fractal_dimension ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 31, 1, 1, 1, 52, 1, 1, 1, 53, 1, 2]
# Gold:  greater ( data = wine_quality , var1 = citric_acid , val = 98.40000045679736 ) <end>
# [1, 1, 1, 1, 52, 1, 1, 53, 1, 2, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  greater ( data = UNK , var1 = citric_acid , val = 98.40000045679736 ) <end>
# [25, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [506, 1, 1, 1, 51, 1, 1, 1, 54, 1, 2, 0, 0, 0, 0]
# Gold:  variance ( data = breast_cancer , var1 = smoothness ) <end>
# [1, 1, 1, 54, 1, 51, 2, 0, 0, 0, 0, 0, 0]
# [25, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  variance ( data = breast_cancer , var1 = smoothness ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 56, 1, 1, 1, 55, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = abalone , var1 = height ) <end>
# [1, 1, 55, 1, 56, 1, 2, 0, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  ranges ( data = abalone , var1 = height ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 92, 1, 1, 1, 57, 1, 1, 1, 58, 1, 2]
# Gold:  greater ( data = wine , var1 = nonflavanoid_phenols , val = 49.08727164698337 ) <end>
# [1, 1, 1, 1, 57, 1, 1, 58, 1, 2, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  greater ( data = UNK , var1 = nonflavanoid_phenols , val = 49.08727164698337 ) <end>
# [21, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [500, 1, 1, 1, 60, 1, 1, 1, 59, 1, 2, 0, 0, 0, 0]
# Gold:  mean ( data = car , var1 = persons ) <end>
# [1, 1, 1, 59, 1, 60, 2, 0, 0, 0, 0, 0, 0]
# [21, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  mean ( data = car , var1 = persons ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 51, 1, 1, 1, 61, 1, 1, 1, 62, 1, 2]
# Gold:  less_eq ( data = breast_cancer , var1 = concave_points , val = 6.3984905113206025 ) <end>
# [1, 1, 1, 1, 61, 1, 1, 1, 62, 1, 2, 0, 0]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = concave_points , val = 6.3984905113206025 ) <end>
# [18, 4, 5, 6, 1, 9, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# [504, 1, 1, 1, 56, 1, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# Gold:  ranges ( data = abalone ) <end>
# [504, 1, 56, 2, 0, 0, 0, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 32, 9, 2, 2, 6, 32, 9, 2, 2, 6, 32]
# Predict:  ranges , val = abalone ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 33, 1, 1, 1, 63, 1, 1, 1, 64, 1, 2]
# Gold:  less_eq ( data = heart_disease , var1 = restecg , val = -82.627676873593 ) <end>
# [1, 1, 1, 1, 63, 1, 1, 1, 1, 1, 64, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = restecg , val = -82.627676873593 ) <end>
# [16, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [502, 1, 1, 1, 56, 1, 1, 1, 65, 1, 2, 0, 0, 0, 0]
# Gold:  maximum ( data = abalone , var1 = sex ) <end>
# [502, 1, 65, 1, 56, 2, 0, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 6, 34, 9, 2, 2, 6, 34]
# Predict:  maximum , val = abalone ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 92, 1, 1, 1, 57, 1, 1, 1, 66, 1, 2]
# Gold:  less_eq ( data = wine , var1 = nonflavanoid_phenols , val = -76.55713235021238 ) <end>
# [1, 1, 1, 1, 57, 1, 1, 1, 517, 1, 66, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = nonflavanoid_phenols , val = -76.55713235021238 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 38, 1, 1, 1, 67, 1, 1, 1, 37, 1, 2]
# Gold:  corr ( data = bank_marketing , var1 = emp.var.rate , var2 = euribor3m ) <end>
# [1, 1, 67, 1, 37, 1, 38, 1, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = bank_marketing , var1 = emp.var.rate , var2 = euribor3m ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 69, 1, 1, 1, 68, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = smartphones , var1 = identifier ) <end>
# [1, 1, 1, 68, 1, 69, 1, 2, 0, 0, 0, 0, 0]
# [19, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  summation ( data = smartphones , var1 = identifier ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 48, 1, 1, 1, 70, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = adult , var1 = hours_per_week ) <end>
# [1, 1, 1, 70, 1, 48, 1, 2, 0, 0, 0, 0, 0]
# [14, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  minimum ( data = adult , var1 = hours_per_week ) <end>
# [21, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [500, 1, 1, 1, 38, 1, 1, 1, 71, 1, 2, 0, 0, 0, 0]
# Gold:  mean ( data = bank_marketing , var1 = day_of_week ) <end>
# [1, 1, 1, 71, 1, 38, 1, 2, 0, 0, 0, 0, 0]
# [21, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 8, 6, 33, 9]
# Predict:  mean ( data = bank_marketing , var1 = day_of_week ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 51, 1, 1, 1, 72, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = breast_cancer , var1 = radius ) <end>
# [503, 1, 1, 72, 1, 51, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 6, 35, 9, 2, 2, 6, 35]
# Predict:  minimum , val = breast_cancer ) <end>
# [21, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [500, 1, 1, 1, 48, 1, 1, 1, 73, 1, 2, 0, 0, 0, 0]
# Gold:  mean ( data = adult , var1 = education_num ) <end>
# [1, 1, 1, 73, 1, 48, 1, 2, 0, 0, 0, 0, 0]
# [21, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 8, 6, 33, 9]
# Predict:  mean ( data = adult , var1 = education_num ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 69, 1, 1, 1, 74, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = smartphones , var1 = triaxial_angular_velocity ) <end>
# [1, 1, 74, 1, 69, 1, 2, 0, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  ranges ( data = smartphones , var1 = triaxial_angular_velocity ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [508, 1, 1, 1, 51, 1, 1, 1, 39, 1, 2, 0, 0, 0, 0]
# Gold:  corr ( data = breast_cancer , var1 = texture ) <end>
# [1, 1, 1, 39, 1, 51, 2, 0, 0, 0, 0, 0, 0]
# [3, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  corr ( data = breast_cancer , var1 = texture ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 31, 1, 1, 1, 30, 1, 1, 1, 75, 1, 2]
# Gold:  greater_eq ( data = wine_quality , var1 = sulphates , val = -82.17391053051787 ) <end>
# [1, 1, 1, 1, 30, 1, 75, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = sulphates , val = -82.17391053051787 ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 31, 1, 1, 1, 76, 1, 1, 1, 77, 1, 2]
# Gold:  scatterplot ( data = wine_quality , var1 = alcohol , var2 = free_sulfur_dioxide ) <end>
# [1, 1, 1, 76, 1, 77, 1, 31, 2]
# [3, 4, 5, 6, 37, 7, 8, 6, 33, 7, 13, 6, 35, 9, 2]
# Predict:  corr ( data = wine_quality , var1 = alcohol , var2 = free_sulfur_dioxide ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 56, 1, 1, 1, 78, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = abalone , var1 = length ) <end>
# [504, 1, 78, 1, 56, 2, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 6, 34, 9, 2, 2, 6, 34]
# Predict:  ranges , val = abalone ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 80, 1, 1, 1, 79, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = iris , var1 = petal_width ) <end>
# [1, 1, 1, 79, 1, 80, 2, 0, 0]
# [19, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  summation ( data = iris , var1 = petal_width ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 69, 1, 1, 1, 81, 1, 1, 1, 82, 1, 2]
# Gold:  scatterplot ( data = smartphones , var1 = label , var2 = 561_feature ) <end>
# [1, 1, 1, 81, 1, 82, 1, 69, 2]
# [3, 4, 5, 6, 37, 7, 8, 6, 33, 7, 13, 6, 35, 9, 2]
# Predict:  corr ( data = smartphones , var1 = label , var2 = 561_feature ) <end>
# [20, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [507, 1, 1, 1, 60, 1, 1, 1, 83, 1, 2, 0, 0, 0, 0]
# Gold:  quantile ( data = car , var1 = doors ) <end>
# [507, 1, 83, 1, 60, 1, 2, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  quantile , val = car ) <end>
# [16, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [502, 1, 1, 1, 38, 1, 1, 1, 44, 1, 2, 0, 0, 0, 0]
# Gold:  maximum ( data = bank_marketing , var1 = marital ) <end>
# [1, 1, 1, 44, 1, 38, 2, 0, 0]
# [16, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  maximum ( data = bank_marketing , var1 = marital ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 31, 1, 1, 1, 84, 1, 1, 1, 85, 1, 2]
# Gold:  scatterplot ( data = wine_quality , var1 = density , var2 = residual_sugar ) <end>
# [513, 1, 84, 1, 85, 1, 31, 1, 2]
# [30, 7, 7, 11, 6, 36, 9, 2, 2, 8, 6, 34, 9, 2, 2]
# Predict:  scatterplot , , val = wine_quality ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 56, 1, 1, 1, 86, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = abalone , var1 = whole_weight ) <end>
# [1, 1, 86, 1, 56, 2, 0, 0, 0]
# [18, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 6, 34, 9]
# Predict:  ranges ( data = abalone , var1 = whole_weight ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 48, 1, 1, 1, 73, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = adult , var1 = education_num ) <end>
# [1, 1, 1, 73, 1, 48, 1, 2, 0]
# [18, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  ranges ( data = adult , var1 = education_num ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 38, 1, 1, 1, 43, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = bank_marketing , var1 = poutcome ) <end>
# [1, 1, 1, 43, 1, 38, 1, 2, 0]
# [14, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  minimum ( data = bank_marketing , var1 = poutcome ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 60, 1, 1, 1, 87, 1, 1, 1, 88, 1, 2]
# Gold:  corr ( data = car , var1 = safety , var2 = maint ) <end>
# [508, 1, 87, 1, 88, 1, 60, 2, 0]
# [30, 7, 7, 11, 6, 34, 9, 2, 2, 6, 36, 9, 2, 2, 6]
# Predict:  corr , , val = maint ) <end>
# [16, 4, 5, 6, 1, 9, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# [502, 1, 1, 1, 31, 1, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# Gold:  maximum ( data = wine_quality ) <end>
# [1, 1, 1, 31, 2, 0, 0, 0, 0]
# [16, 4, 5, 6, 33, 9, 2, 2, 6, 33, 9, 2, 2, 6, 33]
# Predict:  maximum ( data = wine_quality ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 48, 1, 1, 1, 65, 1, 1, 1, 89, 1, 2]
# Gold:  scatterplot ( data = adult , var1 = sex , var2 = fnlwgt ) <end>
# [513, 1, 65, 1, 89, 1, 48, 1, 2]
# [30, 7, 7, 11, 6, 36, 9, 2, 2, 8, 6, 34, 9, 2, 8]
# Predict:  scatterplot , , val = adult ) <end>
# [25, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [506, 1, 1, 1, 38, 1, 1, 1, 67, 1, 2, 0, 0, 0, 0]
# Gold:  variance ( data = bank_marketing , var1 = emp.var.rate ) <end>
# [506, 1, 67, 1, 38, 1, 2, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  variance , val = bank_marketing ) <end>
# [3, 4, 5, 6, 1, 9, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# [508, 1, 1, 1, 48, 1, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# Gold:  corr ( data = adult ) <end>
# [1, 1, 1, 48, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 33, 9, 2, 2, 6, 33, 9, 2, 2, 6, 33]
# Predict:  corr ( data = adult ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 48, 1, 1, 1, 47, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = adult , var1 = occupation ) <end>
# [1, 1, 47, 1, 48, 1, 2, 0, 0]
# [19, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  summation ( data = adult , var1 = occupation ) <end>
# [17, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [509, 1, 1, 1, 80, 1, 1, 1, 79, 1, 2, 0, 0, 0, 0]
# Gold:  histogram ( data = iris , var1 = petal_width ) <end>
# [1, 1, 1, 79, 1, 80, 2, 0, 0]
# [17, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  histogram ( data = iris , var1 = petal_width ) <end>
# [20, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [507, 1, 1, 1, 51, 1, 1, 1, 90, 1, 2, 0, 0, 0, 0]
# Gold:  quantile ( data = breast_cancer , var1 = perimeter ) <end>
# [507, 1, 1, 90, 1, 51, 1, 2, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2, 8]
# Predict:  quantile , val = breast_cancer ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 92, 1, 1, 1, 91, 1, 1, 1, 76, 1, 2]
# Gold:  corr ( data = wine , var1 = magnesium , var2 = alcohol ) <end>
# [508, 1, 91, 1, 76, 1, 92, 1, 2]
# [30, 7, 7, 11, 6, 36, 9, 2, 2, 8, 6, 34, 9, 2, 2]
# Predict:  corr , , val = wine ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 38, 1, 1, 1, 49, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = bank_marketing , var1 = education ) <end>
# [1, 1, 1, 49, 1, 38, 1, 2, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  std ( data = bank_marketing , var1 = education ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 51, 1, 1, 1, 54, 1, 1, 1, 93, 1, 2]
# Gold:  corr ( data = breast_cancer , var1 = smoothness , var2 = symmetry ) <end>
# [508, 1, 54, 1, 93, 1, 51, 2, 0, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 36, 9, 2, 2, 6, 36, 9, 2, 2, 6]
# Predict:  corr , , val = breast_cancer ) <end>
# [20, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [507, 1, 1, 1, 51, 1, 1, 1, 94, 1, 2, 0, 0, 0, 0]
# Gold:  quantile ( data = breast_cancer , var1 = concavity ) <end>
# [507, 1, 94, 1, 51, 1, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  quantile , val = breast_cancer ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 95, 1, 1, 1, 96, 1, 2]
# Gold:  greater_eq ( data = bank_marketing , var1 = cons.price.idx , val = 95.55203375607857 ) <end>
# [1, 1, 1, 1, 95, 518, 1, 1, 1, 1, 96, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = cons.price.idx , val = 95.55203375607857 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 38, 1, 1, 1, 44, 1, 1, 1, 97, 1, 2]
# Gold:  corr ( data = bank_marketing , var1 = marital , var2 = cons.conf.idx ) <end>
# [1, 1, 44, 1, 97, 1, 38, 1, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = bank_marketing , var1 = marital , var2 = cons.conf.idx ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 48, 1, 1, 1, 98, 1, 1, 1, 99, 1, 2]
# Gold:  greater_eq ( data = adult , var1 = relationship , val = -72.35109033417842 ) <end>
# [1, 1, 1, 1, 98, 1, 1, 1, 517, 1, 99, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = relationship , val = -72.35109033417842 ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 51, 1, 1, 1, 93, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = breast_cancer , var1 = symmetry ) <end>
# [1, 1, 1, 93, 1, 51, 1, 2, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  std ( data = breast_cancer , var1 = symmetry ) <end>
# [23, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [517, 1, 1, 1, 35, 1, 1, 1, 100, 1, 1, 1, 101, 1, 2]
# Gold:  equal ( data = forest_fire , var1 = day , val = -97.63743839434558 ) <end>
# [1, 1, 1, 1, 100, 1, 101, 1, 2, 0, 0, 0, 0]
# [23, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  equal ( data = UNK , var1 = day , val = -97.63743839434558 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 35, 1, 1, 1, 102, 1, 1, 1, 103, 1, 2]
# Gold:  corr ( data = forest_fire , var1 = temp , var2 = wind ) <end>
# [508, 1, 102, 1, 103, 1, 35, 2, 0, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 36, 9, 2, 2, 6, 36, 9, 2, 2, 6]
# Predict:  corr , , val = forest_fire ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 48, 1, 1, 1, 70, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = adult , var1 = hours_per_week ) <end>
# [1, 1, 70, 1, 48, 2, 0, 0, 0, 0, 0, 0, 0]
# [14, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 6, 34, 9]
# Predict:  minimum ( data = adult , var1 = hours_per_week ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 48, 1, 1, 1, 73, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = adult , var1 = education_num ) <end>
# [1, 1, 73, 1, 48, 1, 2, 0, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  std ( data = adult , var1 = education_num ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 92, 1, 1, 1, 104, 1, 1, 1, 57, 1, 2]
# Gold:  corr ( data = wine , var1 = total_phenols , var2 = nonflavanoid_phenols ) <end>
# [508, 1, 104, 1, 57, 1, 92, 1, 2, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 36, 9, 2, 8, 6, 34, 9, 2, 8, 6]
# Predict:  corr , , val = wine ) <end>
# [28, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [510, 1, 1, 1, 35, 1, 1, 1, 105, 1, 2, 0, 0, 0, 0]
# Gold:  boxplot ( data = forest_fire , var1 = area ) <end>
# [510, 1, 1, 105, 1, 35, 1, 2, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2, 8]
# Predict:  boxplot , val = forest_fire ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 51, 1, 1, 1, 72, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = breast_cancer , var1 = radius ) <end>
# [1, 1, 72, 1, 51, 2, 0, 0, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 6, 34, 9]
# Predict:  std ( data = breast_cancer , var1 = radius ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 106, 1, 1, 1, 107, 1, 2]
# Gold:  less_eq ( data = bank_marketing , var1 = age , val = 99.52268727482934 ) <end>
# [1, 1, 1, 1, 106, 1, 107, 1, 2, 0, 0, 0, 0]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = age , val = 99.52268727482934 ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 38, 1, 1, 1, 97, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = bank_marketing , var1 = cons.conf.idx ) <end>
# [1, 1, 1, 1, 97, 1, 38, 1, 2, 0, 0, 0, 0]
# [24, 4, 5, 6, 36, 7, 8, 6, 34, 9, 2, 2, 8, 6, 34]
# Predict:  std ( data = bank_marketing , var1 = cons.conf.idx ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 31, 1, 1, 1, 77, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = wine_quality , var1 = free_sulfur_dioxide ) <end>
# [1, 1, 1, 77, 1, 31, 1, 2, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  ranges ( data = wine_quality , var1 = free_sulfur_dioxide ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 48, 1, 1, 1, 98, 1, 1, 1, 108, 1, 2]
# Gold:  greater_eq ( data = adult , var1 = relationship , val = 59.720993911302344 ) <end>
# [1, 1, 1, 1, 98, 518, 1, 1, 517, 1, 108, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = relationship , val = 59.720993911302344 ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 35, 1, 1, 1, 100, 1, 1, 1, 109, 1, 2]
# Gold:  greater ( data = forest_fire , var1 = day , val = 97.81994175545009 ) <end>
# [1, 1, 1, 1, 100, 1, 1, 1, 109, 1, 2, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  greater ( data = UNK , var1 = day , val = 97.81994175545009 ) <end>
# [26, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [516, 1, 1, 1, 38, 1, 1, 1, 110, 1, 1, 1, 111, 1, 2]
# Gold:  less ( data = bank_marketing , var1 = duration , val = 29.657753792154978 ) <end>
# [1, 1, 1, 1, 110, 1, 111, 1, 2, 0, 0, 0, 0]
# [26, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  less ( data = UNK , var1 = duration , val = 29.657753792154978 ) <end>
# [23, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [517, 1, 1, 1, 51, 1, 1, 1, 50, 1, 1, 1, 112, 1, 2]
# Gold:  equal ( data = breast_cancer , var1 = fractal_dimension , val = -59.959601078765836 ) <end>
# [1, 1, 1, 1, 50, 1, 112, 1, 2, 0, 0]
# [23, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  equal ( data = UNK , var1 = fractal_dimension , val = -59.959601078765836 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 51, 1, 1, 1, 50, 1, 1, 1, 113, 1, 2]
# Gold:  greater_eq ( data = breast_cancer , var1 = fractal_dimension , val = -16.99718636266651 ) <end>
# [1, 1, 1, 1, 50, 1, 113, 1, 2, 0, 0]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = fractal_dimension , val = -16.99718636266651 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 92, 1, 1, 1, 57, 1, 1, 1, 114, 1, 2]
# Gold:  greater_eq ( data = wine , var1 = nonflavanoid_phenols , val = -44.06800736120245 ) <end>
# [1, 1, 1, 1, 57, 1, 1, 1, 114, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = nonflavanoid_phenols , val = -44.06800736120245 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 92, 1, 1, 1, 104, 1, 1, 1, 115, 1, 2]
# Gold:  greater_eq ( data = wine , var1 = total_phenols , val = 83.098122539374 ) <end>
# [1, 1, 1, 1, 104, 1, 115, 1, 2, 0, 0]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = total_phenols , val = 83.098122539374 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [508, 1, 1, 1, 92, 1, 1, 1, 91, 1, 2, 0, 0, 0, 0]
# Gold:  corr ( data = wine , var1 = magnesium ) <end>
# [1, 1, 1, 91, 1, 92, 1, 2, 0, 0, 0]
# [3, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 6, 35, 9, 2]
# Predict:  corr ( data = wine , var1 = magnesium ) <end>
# [21, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [500, 1, 1, 1, 38, 1, 1, 1, 116, 1, 2, 0, 0, 0, 0]
# Gold:  mean ( data = bank_marketing , var1 = month ) <end>
# [1, 1, 116, 1, 38, 2, 0, 0, 0, 0, 0]
# [21, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 6, 34, 9]
# Predict:  mean ( data = bank_marketing , var1 = month ) <end>
# [20, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [507, 1, 1, 1, 56, 1, 1, 1, 117, 1, 2, 0, 0, 0, 0]
# Gold:  quantile ( data = abalone , var1 = diameter ) <end>
# [507, 1, 1, 117, 1, 56, 1, 2, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2, 8]
# Predict:  quantile , val = abalone ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 60, 1, 1, 1, 59, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = car , var1 = persons ) <end>
# [1, 1, 1, 59, 1, 60, 1, 2, 0, 0, 0]
# [24, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  std ( data = car , var1 = persons ) <end>
# [16, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [502, 1, 1, 1, 48, 1, 1, 1, 118, 1, 2, 0, 0, 0, 0]
# Gold:  maximum ( data = adult , var1 = native_country ) <end>
# [1, 1, 1, 118, 1, 48, 2, 0, 0, 0, 0]
# [16, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  maximum ( data = adult , var1 = native_country ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 69, 1, 1, 1, 82, 1, 1, 1, 68, 1, 2]
# Gold:  scatterplot ( data = smartphones , var1 = 561_feature , var2 = identifier ) <end>
# [1, 1, 1, 82, 1, 68, 1, 69, 1, 2, 0]
# [15, 4, 5, 6, 37, 7, 8, 6, 33, 7, 13, 6, 35, 9, 2]
# Predict:  scatterplot ( data = smartphones , var1 = 561_feature , var2 = identifier ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 38, 1, 1, 1, 36, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = bank_marketing , var1 = nr.employed ) <end>
# [1, 1, 1, 36, 1, 38, 1, 2, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  std ( data = bank_marketing , var1 = nr.employed ) <end>
# [21, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [500, 1, 1, 1, 69, 1, 1, 1, 82, 1, 2, 0, 0, 0, 0]
# Gold:  mean ( data = smartphones , var1 = 561_feature ) <end>
# [500, 1, 1, 82, 1, 69, 1, 2, 0, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2]
# Predict:  mean , , val = smartphones ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 92, 1, 1, 1, 119, 1, 1, 1, 104, 1, 2]
# Gold:  scatterplot ( data = wine , var1 = ash , var2 = total_phenols ) <end>
# [1, 1, 1, 119, 1, 104, 1, 92, 2, 0, 0, 0, 0]
# [15, 4, 5, 6, 37, 7, 8, 6, 33, 7, 13, 6, 35, 9, 2]
# Predict:  scatterplot ( data = wine , var1 = ash , var2 = total_phenols ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 33, 1, 1, 1, 106, 1, 1, 1, 120, 1, 2]
# Gold:  less_eq ( data = heart_disease , var1 = age , val = -15.310193867407975 ) <end>
# [1, 1, 1, 1, 106, 516, 1, 1, 517, 1, 120, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = age , val = -15.310193867407975 ) <end>
# [16, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [502, 1, 1, 1, 38, 1, 1, 1, 121, 1, 2, 0, 0, 0, 0]
# Gold:  maximum ( data = bank_marketing , var1 = pdays ) <end>
# [1, 1, 121, 1, 38, 1, 2, 0, 0, 0, 0, 0, 0]
# [16, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  maximum ( data = bank_marketing , var1 = pdays ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 38, 1, 1, 1, 122, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = bank_marketing , var1 = job ) <end>
# [1, 1, 122, 1, 38, 1, 2, 0, 0, 0, 0, 0, 0]
# [19, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  summation ( data = bank_marketing , var1 = job ) <end>
# [17, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [509, 1, 1, 1, 35, 1, 1, 1, 102, 1, 2, 0, 0, 0, 0]
# Gold:  histogram ( data = forest_fire , var1 = temp ) <end>
# [509, 1, 102, 1, 35, 1, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  histogram , val = forest_fire ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 51, 1, 1, 1, 61, 1, 1, 1, 72, 1, 2]
# Gold:  corr ( data = breast_cancer , var1 = concave_points , var2 = radius ) <end>
# [1, 1, 61, 1, 72, 1, 51, 1, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = breast_cancer , var1 = concave_points , var2 = radius ) <end>
# [21, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [500, 1, 1, 1, 38, 1, 1, 1, 121, 1, 2, 0, 0, 0, 0]
# Gold:  mean ( data = bank_marketing , var1 = pdays ) <end>
# [1, 1, 1, 121, 1, 38, 2, 0, 0, 0, 0, 0, 0]
# [21, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  mean ( data = bank_marketing , var1 = pdays ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 31, 1, 1, 1, 123, 1, 1, 1, 124, 1, 2]
# Gold:  greater ( data = wine_quality , var1 = chlorides , val = 36.86548429297781 ) <end>
# [1, 1, 1, 1, 123, 1, 1, 124, 1, 2, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  greater ( data = UNK , var1 = chlorides , val = 36.86548429297781 ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 35, 1, 1, 1, 100, 1, 1, 1, 125, 1, 2]
# Gold:  less_eq ( data = forest_fire , var1 = day , val = -41.788490630937126 ) <end>
# [1, 1, 1, 1, 100, 1, 1, 1, 517, 1, 125, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = day , val = -41.788490630937126 ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 116, 1, 1, 1, 126, 1, 2]
# Gold:  less_eq ( data = bank_marketing , var1 = month , val = -2.3660918116330976 ) <end>
# [1, 1, 1, 1, 116, 1, 1, 1, 1, 1, 126, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = month , val = -2.3660918116330976 ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 31, 1, 1, 1, 127, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = wine_quality , var1 = volatile_acidity ) <end>
# [501, 1, 127, 1, 31, 1, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  std , val = wine_quality ) <end>
# [20, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [507, 1, 1, 1, 31, 1, 1, 1, 52, 1, 2, 0, 0, 0, 0]
# Gold:  quantile ( data = wine_quality , var1 = citric_acid ) <end>
# [507, 1, 52, 1, 31, 1, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  quantile , val = wine_quality ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 92, 1, 1, 1, 104, 1, 1, 1, 128, 1, 2]
# Gold:  greater ( data = wine , var1 = total_phenols , val = 74.28290630513715 ) <end>
# [1, 1, 1, 1, 104, 1, 128, 1, 2, 0, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater ( data = UNK , var1 = total_phenols , val = 74.28290630513715 ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 92, 1, 1, 1, 129, 1, 1, 1, 130, 1, 2]
# Gold:  greater ( data = wine , var1 = proanthocyanins , val = -87.30752216940195 ) <end>
# [1, 1, 1, 1, 129, 1, 1, 1, 130, 1, 2, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  greater ( data = UNK , var1 = proanthocyanins , val = -87.30752216940195 ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 51, 1, 1, 1, 94, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = breast_cancer , var1 = concavity ) <end>
# [1, 1, 94, 1, 51, 1, 2, 0, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  ranges ( data = breast_cancer , var1 = concavity ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 92, 1, 1, 1, 131, 1, 1, 1, 132, 1, 2]
# Gold:  greater ( data = wine , var1 = flavanoids , val = 89.3031362646752 ) <end>
# [1, 1, 1, 1, 131, 1, 1, 132, 1, 2, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  greater ( data = UNK , var1 = flavanoids , val = 89.3031362646752 ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 60, 1, 1, 1, 133, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = car , var1 = comfort ) <end>
# [1, 1, 1, 133, 1, 60, 1, 2, 0, 0, 0, 0, 0]
# [19, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  summation ( data = car , var1 = comfort ) <end>
# [26, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [516, 1, 1, 1, 48, 1, 1, 1, 98, 1, 1, 1, 134, 1, 2]
# Gold:  less ( data = adult , var1 = relationship , val = 89.99733285861518 ) <end>
# [1, 1, 1, 1, 98, 516, 1, 134, 1, 2, 0, 0, 0]
# [26, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  less ( data = UNK , var1 = relationship , val = 89.99733285861518 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 80, 1, 1, 1, 135, 1, 1, 1, 136, 1, 2]
# Gold:  greater_eq ( data = iris , var1 = sepal_width , val = 49.12796940927231 ) <end>
# [1, 1, 1, 1, 135, 1, 136, 1, 2, 0, 0, 0, 0]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = sepal_width , val = 49.12796940927231 ) <end>
# [23, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [517, 1, 1, 1, 35, 1, 1, 1, 34, 1, 1, 1, 137, 1, 2]
# Gold:  equal ( data = forest_fire , var1 = y , val = 33.678162402501954 ) <end>
# [1, 1, 1, 1, 34, 1, 1, 1, 137, 1, 2, 0, 0]
# [23, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  equal ( data = UNK , var1 = y , val = 33.678162402501954 ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 35, 1, 1, 1, 103, 1, 1, 1, 138, 1, 2]
# Gold:  less_eq ( data = forest_fire , var1 = wind , val = 52.447137700071494 ) <end>
# [1, 1, 1, 1, 103, 1, 1, 1, 1, 1, 138, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = wind , val = 52.447137700071494 ) <end>
# [16, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [502, 1, 1, 1, 48, 1, 1, 1, 139, 1, 2, 0, 0, 0, 0]
# Gold:  maximum ( data = adult , var1 = marital_status ) <end>
# [502, 1, 1, 139, 1, 48, 1, 2, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2, 8]
# Predict:  maximum , val = adult ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 48, 1, 1, 1, 118, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = adult , var1 = native_country ) <end>
# [1, 1, 118, 1, 48, 1, 2, 0, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  std ( data = adult , var1 = native_country ) <end>
# [20, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [507, 1, 1, 1, 48, 1, 1, 1, 140, 1, 2, 0, 0, 0, 0]
# Gold:  quantile ( data = adult , var1 = capital_gain ) <end>
# [507, 1, 1, 140, 1, 48, 1, 2, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2, 8]
# Predict:  quantile , val = adult ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 92, 1, 1, 1, 141, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = wine , var1 = varor_intensity ) <end>
# [504, 1, 1, 141, 1, 92, 1, 2, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2, 8]
# Predict:  ranges , val = wine ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 142, 1, 1, 1, 143, 1, 2]
# Gold:  less_eq ( data = bank_marketing , var1 = previous , val = 67.87690310523828 ) <end>
# [1, 1, 1, 1, 142, 1, 1, 1, 517, 1, 143, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = previous , val = 67.87690310523828 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [508, 1, 1, 1, 35, 1, 1, 1, 144, 1, 2, 0, 0, 0, 0]
# Gold:  corr ( data = forest_fire , var1 = rain ) <end>
# [1, 1, 144, 1, 35, 1, 2, 0, 0, 0, 0, 0, 0]
# [3, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 6, 34, 9, 2]
# Predict:  corr ( data = forest_fire , var1 = rain ) <end>
# [25, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [506, 1, 1, 1, 48, 1, 1, 1, 73, 1, 2, 0, 0, 0, 0]
# Gold:  variance ( data = adult , var1 = education_num ) <end>
# [506, 1, 73, 1, 48, 1, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 34, 9, 2, 2, 8]
# Predict:  variance , val = adult ) <end>
# [25, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [506, 1, 1, 1, 35, 1, 1, 1, 105, 1, 2, 0, 0, 0, 0]
# Gold:  variance ( data = forest_fire , var1 = area ) <end>
# [1, 1, 1, 105, 1, 35, 1, 2, 0, 0, 0, 0, 0]
# [25, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  variance ( data = forest_fire , var1 = area ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 48, 1, 1, 1, 98, 1, 1, 1, 89, 1, 2]
# Gold:  corr ( data = adult , var1 = relationship , var2 = fnlwgt ) <end>
# [508, 1, 98, 1, 89, 1, 48, 1, 2, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 36, 9, 2, 2, 8, 6, 34, 9, 2, 8]
# Predict:  corr , , val = adult ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 31, 1, 1, 1, 84, 1, 1, 1, 145, 1, 2]
# Gold:  greater_eq ( data = wine_quality , var1 = density , val = -46.01876596577053 ) <end>
# [1, 1, 1, 1, 84, 1, 145, 1, 2, 0, 0, 0, 0]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = density , val = -46.01876596577053 ) <end>
# [16, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [502, 1, 1, 1, 31, 1, 1, 1, 85, 1, 2, 0, 0, 0, 0]
# Gold:  maximum ( data = wine_quality , var1 = residual_sugar ) <end>
# [1, 1, 1, 85, 1, 31, 2, 0, 0, 0, 0, 0, 0]
# [16, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  maximum ( data = wine_quality , var1 = residual_sugar ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [508, 1, 1, 1, 51, 1, 1, 1, 94, 1, 2, 0, 0, 0, 0]
# Gold:  corr ( data = breast_cancer , var1 = concavity ) <end>
# [1, 1, 94, 1, 51, 1, 2, 0, 0, 0, 0, 0, 0]
# [3, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 6, 34, 9, 2]
# Predict:  corr ( data = breast_cancer , var1 = concavity ) <end>
# [17, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [509, 1, 1, 1, 80, 1, 1, 1, 135, 1, 2, 0, 0, 0, 0]
# Gold:  histogram ( data = iris , var1 = sepal_width ) <end>
# [509, 1, 1, 135, 1, 80, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 6, 35, 9, 2, 2, 6, 35]
# Predict:  histogram , val = iris ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 33, 1, 1, 1, 106, 1, 1, 1, 32, 1, 2]
# Gold:  corr ( data = heart_disease , var1 = age , var2 = fbs ) <end>
# [1, 1, 106, 1, 32, 1, 33, 1, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = heart_disease , var1 = age , var2 = fbs ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 92, 1, 1, 1, 129, 1, 1, 1, 146, 1, 2]
# Gold:  greater_eq ( data = wine , var1 = proanthocyanins , val = 91.91651861323692 ) <end>
# [1, 1, 1, 1, 129, 1, 1, 1, 517, 1, 146, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = proanthocyanins , val = 91.91651861323692 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 51, 1, 1, 1, 54, 1, 1, 1, 147, 1, 2]
# Gold:  greater_eq ( data = breast_cancer , var1 = smoothness , val = 2.119519653636786 ) <end>
# [1, 1, 1, 1, 54, 1, 147, 1, 2, 0, 0, 0, 0]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = smoothness , val = 2.119519653636786 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 60, 1, 1, 1, 59, 1, 1, 1, 148, 1, 2]
# Gold:  greater_eq ( data = car , var1 = persons , val = -63.26620807956127 ) <end>
# [1, 1, 1, 1, 59, 1, 1, 1, 1, 1, 148, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = persons , val = -63.26620807956127 ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 92, 1, 1, 1, 149, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = wine , var1 = alcalinity_of_ash ) <end>
# [504, 1, 149, 1, 92, 1, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  ranges , val = wine ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [508, 1, 1, 1, 51, 1, 1, 1, 61, 1, 2, 0, 0, 0, 0]
# Gold:  corr ( data = breast_cancer , var1 = concave_points ) <end>
# [1, 1, 61, 1, 51, 1, 2, 0, 0, 0, 0, 0, 0]
# [3, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 6, 34, 9, 2]
# Predict:  corr ( data = breast_cancer , var1 = concave_points ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 56, 1, 1, 1, 150, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = abalone , var1 = shucked_weight ) <end>
# [1, 1, 1, 150, 1, 56, 2, 0, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  ranges ( data = abalone , var1 = shucked_weight ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 35, 1, 1, 1, 144, 1, 1, 1, 151, 1, 2]
# Gold:  greater_eq ( data = forest_fire , var1 = rain , val = -11.595622793407088 ) <end>
# [1, 1, 1, 1, 144, 1, 1, 1, 151, 1, 2, 0, 0]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = rain , val = -11.595622793407088 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 48, 1, 1, 1, 118, 1, 1, 1, 152, 1, 2]
# Gold:  greater_eq ( data = adult , var1 = native_country , val = -56.31188688808213 ) <end>
# [1, 1, 1, 1, 118, 518, 1, 1, 517, 1, 152, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = native_country , val = -56.31188688808213 ) <end>
# [16, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [502, 1, 1, 1, 31, 1, 1, 1, 77, 1, 2, 0, 0, 0, 0]
# Gold:  maximum ( data = wine_quality , var1 = free_sulfur_dioxide ) <end>
# [502, 1, 77, 1, 31, 1, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  maximum , val = wine_quality ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 38, 1, 1, 1, 97, 1, 1, 1, 153, 1, 2]
# Gold:  scatterplot ( data = bank_marketing , var1 = cons.conf.idx , var2 = loan ) <end>
# [1, 1, 1, 97, 1, 153, 1, 38, 1, 2, 0, 0, 0]
# [15, 4, 5, 6, 37, 7, 8, 6, 33, 7, 13, 6, 35, 9, 2]
# Predict:  scatterplot ( data = bank_marketing , var1 = cons.conf.idx , var2 = loan ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 69, 1, 1, 1, 74, 1, 1, 1, 154, 1, 2]
# Gold:  greater_eq ( data = smartphones , var1 = triaxial_angular_velocity , val = -37.044264488773315 ) <end>
# [1, 1, 1, 1, 74, 1, 1, 1, 1, 1, 154, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = triaxial_angular_velocity , val = -37.044264488773315 ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 48, 1, 1, 1, 155, 1, 1, 1, 156, 1, 2]
# Gold:  greater ( data = adult , var1 = capital_loss , val = 67.00516365149508 ) <end>
# [1, 1, 1, 1, 155, 1, 1, 156, 1, 2, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  greater ( data = UNK , var1 = capital_loss , val = 67.00516365149508 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 92, 1, 1, 1, 149, 1, 1, 1, 157, 1, 2]
# Gold:  corr ( data = wine , var1 = alcalinity_of_ash , var2 = malic_acid ) <end>
# [1, 1, 149, 1, 157, 1, 92, 1, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = wine , var1 = alcalinity_of_ash , var2 = malic_acid ) <end>
# [23, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [517, 1, 1, 1, 35, 1, 1, 1, 116, 1, 1, 1, 158, 1, 2]
# Gold:  equal ( data = forest_fire , var1 = month , val = 71.37552914063994 ) <end>
# [1, 1, 1, 1, 116, 1, 158, 1, 2, 0, 0, 0, 0]
# [23, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  equal ( data = UNK , var1 = month , val = 71.37552914063994 ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 60, 1, 1, 1, 88, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = car , var1 = maint ) <end>
# [1, 1, 1, 88, 1, 60, 2, 0, 0, 0, 0, 0, 0]
# [14, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  minimum ( data = car , var1 = maint ) <end>
# [28, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [510, 1, 1, 1, 35, 1, 1, 1, 116, 1, 2, 0, 0, 0, 0]
# Gold:  boxplot ( data = forest_fire , var1 = month ) <end>
# [510, 1, 1, 116, 1, 35, 1, 2, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2, 8]
# Predict:  boxplot , val = forest_fire ) <end>
# [29, 4, 5, 6, 1, 9, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# [512, 1, 1, 1, 33, 1, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# Gold:  describe ( data = heart_disease ) <end>
# [512, 1, 33, 2, 0, 0, 0, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 32, 9, 2, 2, 6, 32, 9, 2, 2, 6, 32]
# Predict:  describe , val = heart_disease ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 56, 1, 1, 1, 150, 1, 1, 1, 159, 1, 2]
# Gold:  greater_eq ( data = abalone , var1 = shucked_weight , val = -97.93330096882602 ) <end>
# [1, 1, 1, 1, 150, 1, 1, 1, 1, 1, 159, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = shucked_weight , val = -97.93330096882602 ) <end>
# [17, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [509, 1, 1, 1, 31, 1, 1, 1, 160, 1, 2, 0, 0, 0, 0]
# Gold:  histogram ( data = wine_quality , var1 = fixed_acidity ) <end>
# [1, 1, 160, 1, 31, 1, 2, 0, 0, 0, 0, 0, 0]
# [17, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  histogram ( data = wine_quality , var1 = fixed_acidity ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 38, 1, 1, 1, 71, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = bank_marketing , var1 = day_of_week ) <end>
# [1, 1, 1, 71, 1, 38, 2, 0, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  std ( data = bank_marketing , var1 = day_of_week ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 51, 1, 1, 1, 61, 1, 1, 1, 161, 1, 2]
# Gold:  greater_eq ( data = breast_cancer , var1 = concave_points , val = 59.454102413805 ) <end>
# [1, 1, 1, 1, 61, 1, 1, 1, 1, 1, 161, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = concave_points , val = 59.454102413805 ) <end>
# [23, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [517, 1, 1, 1, 33, 1, 1, 1, 162, 1, 1, 1, 163, 1, 2]
# Gold:  equal ( data = heart_disease , var1 = trestbps , val = -18.500971858670283 ) <end>
# [1, 1, 1, 1, 162, 1, 1, 1, 163, 1, 2, 0, 0]
# [23, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  equal ( data = UNK , var1 = trestbps , val = -18.500971858670283 ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 56, 1, 1, 1, 150, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = abalone , var1 = shucked_weight ) <end>
# [503, 1, 150, 1, 56, 2, 0, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 6, 34, 9, 2, 2, 6, 34]
# Predict:  minimum , val = abalone ) <end>
# [20, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [507, 1, 1, 1, 56, 1, 1, 1, 164, 1, 2, 0, 0, 0, 0]
# Gold:  quantile ( data = abalone , var1 = shell_weight ) <end>
# [507, 1, 164, 1, 56, 1, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 8, 6, 32, 9, 2, 2, 8]
# Predict:  quantile , val = abalone ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 35, 1, 1, 1, 105, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = forest_fire , var1 = area ) <end>
# [501, 1, 1, 105, 1, 35, 2, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 35, 9, 2, 2, 6, 35, 9, 2, 2, 6, 35]
# Predict:  std , val = forest_fire ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 51, 1, 1, 1, 39, 1, 1, 1, 165, 1, 2]
# Gold:  greater_eq ( data = breast_cancer , var1 = texture , val = 55.06806449350631 ) <end>
# [1, 1, 1, 1, 39, 518, 1, 1, 1, 1, 165, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = texture , val = 55.06806449350631 ) <end>
# [16, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [502, 1, 1, 1, 48, 1, 1, 1, 155, 1, 2, 0, 0, 0, 0]
# Gold:  maximum ( data = adult , var1 = capital_loss ) <end>
# [1, 1, 1, 155, 1, 48, 2, 0, 0, 0, 0, 0, 0]
# [16, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  maximum ( data = adult , var1 = capital_loss ) <end>
# [19, 4, 5, 6, 1, 9, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# [505, 1, 1, 1, 38, 1, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# Gold:  summation ( data = bank_marketing ) <end>
# [1, 1, 1, 38, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# [19, 4, 5, 6, 33, 9, 2, 2, 6, 33, 9, 2, 2, 6, 33]
# Predict:  summation ( data = bank_marketing ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 92, 1, 1, 1, 157, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = wine , var1 = malic_acid ) <end>
# [501, 1, 157, 1, 92, 1, 2, 0, 0, 0, 0, 0, 0]
# ...
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 60, 1, 1, 1, 268, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = car , var1 = buying ) <end>
# [1, 1, 1, 268, 1, 60, 1, 2, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  ranges ( data = car , var1 = buying ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 48, 1, 1, 1, 70, 1, 1, 1, 477, 1, 2]
# Gold:  less_eq ( data = adult , var1 = hours_per_week , val = 21.64736202838739 ) <end>
# [1, 1, 1, 1, 70, 1, 1, 1, 1, 1, 477, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = hours_per_week , val = 21.64736202838739 ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 38, 1, 1, 1, 37, 1, 1, 1, 478, 1, 2]
# Gold:  greater ( data = bank_marketing , var1 = euribor3m , val = 54.835860544565605 ) <end>
# [1, 1, 1, 1, 37, 1, 1, 478, 1, 2, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  greater ( data = UNK , var1 = euribor3m , val = 54.835860544565605 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 56, 1, 1, 1, 65, 1, 1, 1, 150, 1, 2]
# Gold:  corr ( data = abalone , var1 = sex , var2 = shucked_weight ) <end>
# [1, 1, 65, 1, 150, 1, 56, 2, 0, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = abalone , var1 = sex , var2 = shucked_weight ) <end>
# [26, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [516, 1, 1, 1, 92, 1, 1, 1, 76, 1, 1, 1, 479, 1, 2]
# Gold:  less ( data = wine , var1 = alcohol , val = 33.200576091123025 ) <end>
# [1, 1, 1, 1, 76, 1, 479, 1, 2, 0, 0, 0, 0]
# [26, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  less ( data = UNK , var1 = alcohol , val = 33.200576091123025 ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 80, 1, 1, 1, 79, 1, 1, 1, 480, 1, 2]
# Gold:  greater ( data = iris , var1 = petal_width , val = -63.3847013276742 ) <end>
# [1, 1, 1, 1, 79, 518, 1, 480, 1, 2, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  greater ( data = UNK , var1 = petal_width , val = -63.3847013276742 ) <end>
# [21, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [500, 1, 1, 1, 48, 1, 1, 1, 139, 1, 2, 0, 0, 0, 0]
# Gold:  mean ( data = adult , var1 = marital_status ) <end>
# [500, 1, 1, 139, 1, 48, 1, 2, 0, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 2]
# Predict:  mean , , val = adult ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 121, 1, 1, 1, 481, 1, 2]
# Gold:  less_eq ( data = bank_marketing , var1 = pdays , val = 91.75660100693969 ) <end>
# [1, 1, 1, 1, 121, 1, 1, 1, 1, 1, 481, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = pdays , val = 91.75660100693969 ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 33, 1, 1, 1, 63, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = heart_disease , var1 = restecg ) <end>
# [1, 1, 63, 1, 33, 1, 2, 0, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  std ( data = heart_disease , var1 = restecg ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 60, 1, 1, 1, 133, 1, 1, 1, 482, 1, 2]
# Gold:  less_eq ( data = car , var1 = comfort , val = 29.04358937994681 ) <end>
# [1, 1, 1, 1, 133, 1, 1, 1, 517, 1, 482, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = comfort , val = 29.04358937994681 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 60, 1, 1, 1, 268, 1, 1, 1, 83, 1, 2]
# Gold:  corr ( data = car , var1 = buying , var2 = doors ) <end>
# [1, 1, 268, 1, 83, 1, 60, 1, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = car , var1 = buying , var2 = doors ) <end>
# [23, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [517, 1, 1, 1, 38, 1, 1, 1, 110, 1, 1, 1, 483, 1, 2]
# Gold:  equal ( data = bank_marketing , var1 = duration , val = 93.7890509304095 ) <end>
# [1, 1, 1, 1, 110, 1, 483, 1, 2, 0, 0, 0, 0]
# [23, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  equal ( data = UNK , var1 = duration , val = 93.7890509304095 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 48, 1, 1, 1, 118, 1, 1, 1, 484, 1, 2]
# Gold:  greater_eq ( data = adult , var1 = native_country , val = 8.633599414542672 ) <end>
# [1, 1, 1, 1, 118, 1, 1, 1, 1, 1, 484, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = native_country , val = 8.633599414542672 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [508, 1, 1, 1, 33, 1, 1, 1, 162, 1, 2, 0, 0, 0, 0]
# Gold:  corr ( data = heart_disease , var1 = trestbps ) <end>
# [508, 1, 1, 162, 1, 33, 1, 2, 0, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 35, 9, 2, 2, 8, 6, 33, 9, 2, 8]
# Predict:  corr , , val = heart_disease ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 92, 1, 1, 1, 76, 1, 1, 1, 157, 1, 2]
# Gold:  corr ( data = wine , var1 = alcohol , var2 = malic_acid ) <end>
# [508, 1, 76, 1, 157, 1, 92, 2, 0, 0, 0, 0, 0]
# [30, 7, 7, 11, 6, 36, 9, 2, 2, 6, 36, 9, 2, 2, 6]
# Predict:  corr , , val = wine ) <end>
# [24, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [501, 1, 1, 1, 56, 1, 1, 1, 150, 1, 2, 0, 0, 0, 0]
# Gold:  std ( data = abalone , var1 = shucked_weight ) <end>
# [1, 1, 1, 150, 1, 56, 1, 2, 0, 0, 0, 0, 0]
# [24, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  std ( data = abalone , var1 = shucked_weight ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 121, 1, 1, 1, 485, 1, 2]
# Gold:  less_eq ( data = bank_marketing , var1 = pdays , val = -11.302919752515919 ) <end>
# [1, 1, 1, 1, 121, 1, 1, 1, 517, 1, 485, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = pdays , val = -11.302919752515919 ) <end>
# [17, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [509, 1, 1, 1, 38, 1, 1, 1, 44, 1, 2, 0, 0, 0, 0]
# Gold:  histogram ( data = bank_marketing , var1 = marital ) <end>
# [1, 1, 1, 44, 1, 38, 1, 2, 0, 0, 0, 0, 0]
# [17, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  histogram ( data = bank_marketing , var1 = marital ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 33, 1, 1, 1, 180, 1, 1, 1, 486, 1, 2]
# Gold:  greater_eq ( data = heart_disease , var1 = chol , val = -20.040835958909355 ) <end>
# [1, 1, 1, 1, 180, 1, 1, 1, 517, 1, 486, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = chol , val = -20.040835958909355 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 38, 1, 1, 1, 241, 1, 1, 1, 43, 1, 2]
# Gold:  corr ( data = bank_marketing , var1 = housing , var2 = poutcome ) <end>
# [1, 1, 241, 1, 43, 1, 38, 1, 2, 0, 0, 0, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = bank_marketing , var1 = housing , var2 = poutcome ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 48, 1, 1, 1, 73, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = adult , var1 = education_num ) <end>
# [1, 1, 1, 73, 1, 48, 1, 2, 0, 0, 0, 0, 0]
# [14, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  minimum ( data = adult , var1 = education_num ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 241, 1, 1, 1, 487, 1, 2]
# Gold:  greater_eq ( data = bank_marketing , var1 = housing , val = -98.28056689248032 ) <end>
# [1, 1, 1, 1, 241, 1, 1, 1, 1, 1, 487, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = housing , val = -98.28056689248032 ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 35, 1, 1, 1, 116, 1, 1, 1, 488, 1, 2]
# Gold:  greater ( data = forest_fire , var1 = month , val = -67.874936655899 ) <end>
# [1, 1, 1, 1, 116, 1, 488, 1, 2, 0, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater ( data = UNK , var1 = month , val = -67.874936655899 ) <end>
# [17, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [509, 1, 1, 1, 48, 1, 1, 1, 41, 1, 2, 0, 0, 0, 0]
# Gold:  histogram ( data = adult , var1 = race ) <end>
# [1, 1, 1, 41, 1, 48, 1, 2, 0, 0, 0, 0, 0]
# [17, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  histogram ( data = adult , var1 = race ) <end>
# [17, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [509, 1, 1, 1, 48, 1, 1, 1, 139, 1, 2, 0, 0, 0, 0]
# Gold:  histogram ( data = adult , var1 = marital_status ) <end>
# [1, 1, 139, 1, 48, 1, 2, 0, 0, 0, 0, 0, 0]
# [17, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  histogram ( data = adult , var1 = marital_status ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 35, 1, 1, 1, 103, 1, 1, 1, 489, 1, 2]
# Gold:  greater_eq ( data = forest_fire , var1 = wind , val = -19.173704692293555 ) <end>
# [1, 1, 1, 1, 103, 518, 1, 1, 1, 1, 489, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = wind , val = -19.173704692293555 ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 48, 1, 1, 1, 70, 1, 1, 1, 490, 1, 2]
# Gold:  less_eq ( data = adult , var1 = hours_per_week , val = -85.58049967771464 ) <end>
# [1, 1, 1, 1, 70, 1, 1, 1, 1, 1, 490, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = hours_per_week , val = -85.58049967771464 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 31, 1, 1, 1, 76, 1, 1, 1, 491, 1, 2]
# Gold:  greater_eq ( data = wine_quality , var1 = alcohol , val = 33.426060464304385 ) <end>
# [1, 1, 1, 1, 76, 1, 491, 1, 2, 0, 0, 0, 0]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = alcohol , val = 33.426060464304385 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 49, 1, 1, 1, 492, 1, 2]
# Gold:  greater_eq ( data = bank_marketing , var1 = education , val = -44.63634942314989 ) <end>
# [1, 1, 1, 1, 49, 1, 1, 1, 517, 1, 492, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = education , val = -44.63634942314989 ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 60, 1, 1, 1, 59, 1, 1, 1, 493, 1, 2]
# Gold:  greater_eq ( data = car , var1 = persons , val = 88.98543732159999 ) <end>
# [1, 1, 1, 1, 59, 1, 1, 1, 1, 1, 493, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = persons , val = 88.98543732159999 ) <end>
# [10, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [518, 1, 1, 1, 38, 1, 1, 1, 106, 1, 1, 1, 494, 1, 2]
# Gold:  greater ( data = bank_marketing , var1 = age , val = 86.61959298188219 ) <end>
# [1, 1, 1, 1, 106, 1, 494, 1, 2, 0, 0, 0, 0]
# [10, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 36, 9, 2]
# Predict:  greater ( data = UNK , var1 = age , val = 86.61959298188219 ) <end>
# [23, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [517, 1, 1, 1, 38, 1, 1, 1, 121, 1, 1, 1, 495, 1, 2]
# Gold:  equal ( data = bank_marketing , var1 = pdays , val = -27.803692149638493 ) <end>
# [1, 1, 1, 1, 121, 1, 1, 1, 495, 1, 2, 0, 0]
# [23, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  equal ( data = UNK , var1 = pdays , val = -27.803692149638493 ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 35, 1, 1, 1, 215, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = forest_fire , var1 = DC ) <end>
# [1, 1, 215, 1, 35, 1, 2, 0, 0, 0, 0, 0, 0]
# [19, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 8, 6, 32]
# Predict:  summation ( data = forest_fire , var1 = DC ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [508, 1, 1, 1, 33, 1, 1, 1, 162, 1, 2, 0, 0, 0, 0]
# Gold:  corr ( data = heart_disease , var1 = trestbps ) <end>
# [1, 1, 1, 162, 1, 33, 1, 2, 0, 0, 0, 0, 0]
# [3, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 6, 35, 9, 2]
# Predict:  corr ( data = heart_disease , var1 = trestbps ) <end>
# [21, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [500, 1, 1, 1, 60, 1, 1, 1, 133, 1, 2, 0, 0, 0, 0]
# Gold:  mean ( data = car , var1 = comfort ) <end>
# [1, 1, 133, 1, 60, 2, 0, 0, 0, 0, 0, 0, 0]
# [21, 4, 5, 6, 34, 7, 8, 6, 32, 9, 2, 2, 6, 34, 9]
# Predict:  mean ( data = car , var1 = comfort ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 35, 1, 1, 1, 102, 1, 1, 1, 496, 1, 2]
# Gold:  greater_eq ( data = forest_fire , var1 = temp , val = 28.387801801050585 ) <end>
# [1, 1, 1, 1, 102, 1, 1, 1, 1, 1, 496, 1, 2]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = temp , val = 28.387801801050585 ) <end>
# [18, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [504, 1, 1, 1, 92, 1, 1, 1, 57, 1, 2, 0, 0, 0, 0]
# Gold:  ranges ( data = wine , var1 = nonflavanoid_phenols ) <end>
# [1, 1, 1, 57, 1, 92, 2, 0, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 6, 35, 9]
# Predict:  ranges ( data = wine , var1 = nonflavanoid_phenols ) <end>
# [15, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [513, 1, 1, 1, 60, 1, 1, 1, 59, 1, 1, 1, 87, 1, 2]
# Gold:  scatterplot ( data = car , var1 = persons , var2 = safety ) <end>
# [1, 1, 1, 59, 1, 87, 1, 60, 1, 2, 0, 0, 0]
# [15, 4, 5, 6, 37, 7, 8, 6, 33, 7, 13, 6, 35, 9, 2]
# Predict:  scatterplot ( data = car , var1 = persons , var2 = safety ) <end>
# [28, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [510, 1, 1, 1, 38, 1, 1, 1, 153, 1, 2, 0, 0, 0, 0]
# Gold:  boxplot ( data = bank_marketing , var1 = loan ) <end>
# [510, 1, 153, 1, 38, 2, 0, 0, 0, 0, 0, 0, 0]
# [30, 7, 11, 6, 34, 9, 2, 2, 6, 34, 9, 2, 2, 6, 34]
# Predict:  boxplot , val = bank_marketing ) <end>
# [22, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 69, 1, 1, 1, 82, 1, 1, 1, 497, 1, 2]
# Gold:  greater_eq ( data = smartphones , var1 = 561_feature , val = -32.3402877718884 ) <end>
# [1, 1, 1, 1, 82, 1, 1, 1, 497, 1, 2, 0, 0]
# [22, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 38, 9, 2]
# Predict:  greater_eq ( data = UNK , var1 = 561_feature , val = -32.3402877718884 ) <end>
# [12, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [1, 1, 1, 1, 38, 1, 1, 1, 110, 1, 1, 1, 498, 1, 2]
# Gold:  less_eq ( data = bank_marketing , var1 = duration , val = 0.31166049180295374 ) <end>
# [1, 1, 1, 1, 110, 1, 1, 1, 517, 1, 498, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 40, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = duration , val = 0.31166049180295374 ) <end>
# [14, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [503, 1, 1, 1, 51, 1, 1, 1, 54, 1, 2, 0, 0, 0, 0]
# Gold:  minimum ( data = breast_cancer , var1 = smoothness ) <end>
# [1, 1, 1, 54, 1, 51, 1, 2, 0, 0]
# [14, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  minimum ( data = breast_cancer , var1 = smoothness ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 48, 1, 1, 1, 47, 1, 1, 1, 98, 1, 2]
# Gold:  corr ( data = adult , var1 = occupation , var2 = relationship ) <end>
# [508, 1, 47, 1, 98, 1, 48, 1, 2, 0]
# [30, 7, 7, 11, 6, 36, 9, 2, 2, 8, 6, 34, 9, 2, 8]
# Predict:  corr , , val = adult ) <end>
# [18, 4, 5, 6, 1, 9, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# [504, 1, 1, 1, 38, 1, 2, 0, 0, 0, 0, 0, 0, 0, 0]
# Gold:  ranges ( data = bank_marketing ) <end>
# [1, 1, 1, 38, 2, 0, 0, 0, 0, 0]
# [18, 4, 5, 6, 33, 9, 2, 2, 6, 33, 9, 2, 2, 6, 33]
# Predict:  ranges ( data = bank_marketing ) <end>
# [19, 4, 5, 6, 1, 7, 8, 6, 1, 9, 2, 0, 0, 0, 0]
# [505, 1, 1, 1, 80, 1, 1, 1, 79, 1, 2, 0, 0, 0, 0]
# Gold:  summation ( data = iris , var1 = petal_width ) <end>
# [1, 1, 1, 79, 1, 80, 1, 2, 0, 0]
# [19, 4, 5, 6, 35, 7, 8, 6, 33, 9, 2, 2, 8, 6, 33]
# Predict:  summation ( data = iris , var1 = petal_width ) <end>
# [26, 4, 5, 6, 1, 7, 8, 6, 1, 7, 11, 6, 1, 9, 2]
# [516, 1, 1, 1, 69, 1, 1, 1, 82, 1, 1, 1, 499, 1, 2]
# Gold:  less ( data = smartphones , var1 = 561_feature , val = -46.725008138290946 ) <end>
# [1, 1, 1, 1, 82, 1, 1, 499, 1, 2]
# [12, 4, 5, 6, 1, 7, 8, 6, 34, 7, 11, 6, 37, 9, 2]
# Predict:  less_eq ( data = UNK , var1 = 561_feature , val = -46.725008138290946 ) <end>
# [3, 4, 5, 6, 1, 7, 8, 6, 1, 7, 13, 6, 1, 9, 2]
# [508, 1, 1, 1, 48, 1, 1, 1, 65, 1, 1, 1, 47, 1, 2]
# Gold:  corr ( data = adult , var1 = sex , var2 = occupation ) <end>
# [1, 1, 65, 1, 47, 1, 48, 1, 2, 0]
# [3, 4, 5, 6, 36, 7, 8, 6, 32, 7, 13, 6, 34, 9, 2]
# Predict:  corr ( data = adult , var1 = sex , var2 = occupation ) <end>
# accuracy 0.4174757281553398

# %%
print([(ex.x_str, ex.y_str) for ex in test_exs])
# Out:
# [('average of the free_sulfur_dioxide in wine_quality', 'mean ( data = wine_quality , var1 = free_sulfur_dioxide )'), ('quantity of the month in bank_marketing', 'summation ( data = bank_marketing , var1 = month )'), ('corr between campaign and housing in bank_marketing', 'corr ( data = bank_marketing , var1 = campaign , var2 = housing )'), ('number of entries  label  <=  67.84235027943183 dataset', 'less_eq ( data = smartphones , var1 = label , val = 67.84235027943183 )'), ('corr of sex in adult dataset', 'corr ( data = adult , var1 = sex )'), ('number of rows with duration  <  60.18263772552291 data', 'less ( data = bank_marketing , var1 = duration , val = 60.18263772552291 )'), ('how many data  hue   ==   35.364650075899476 ', 'equal ( data = wine , var1 = hue , val = 35.364650075899476 )'), ('corr of education_num with relationship in adult data', 'corr ( data = adult , var1 = education_num , var2 = relationship )'), ('variance of volatile_acidity in wine_quality dataset', 'variance ( data = wine_quality , var1 = volatile_acidity )'), ('scatterplot between alcohol with flavanoids in wine data', 'scatterplot ( data = wine , var1 = alcohol , var2 = flavanoids )'), ('how many entries where area smaller than 78.63614259508398 df', 'less ( data = forest_fire , var1 = area , val = 78.63614259508398 )'), ('cor of isi and temp in forest_fire', 'corr ( data = forest_fire , var1 = ISI , var2 = temp )'), ('deviation of marital_status in adult df', 'std ( data = adult , var1 = marital_status )'), ('min of compactness in breast_cancer', 'minimum ( data = breast_cancer , var1 = compactness )'), ('number of data with volatile_acidity larger than or same as 67.22352533891933 df', 'greater_eq ( data = wine_quality , var1 = volatile_acidity , val = 67.22352533891933 )'), ('histogram of age in heart_disease df', 'histogram ( data = heart_disease , var1 = age )'), ('number of data where cp smaller than or same as -63.46865458159265 ', 'less_eq ( data = heart_disease , var1 = cp , val = -63.46865458159265 )'), ('how many info with job greater than -2.4916677700560967 df', 'greater ( data = bank_marketing , var1 = job , val = -2.4916677700560967 )'), ('correlation of diameter in abalone data', 'corr ( data = abalone , var1 = diameter )'), ('sparsity of the breast_cancer', 'variance ( data = breast_cancer )'), ('number of info with height   >   47.11356029655528 dataset', 'greater ( data = abalone , var1 = height , val = 47.11356029655528 )'), ('how many entries with 561_feature   >   -3.2312734811244894 df', 'greater ( data = smartphones , var1 = 561_feature , val = -3.2312734811244894 )'), ('store abalone df  in d', 'load ( data = abalone )'), ('var of dc in forest_fire dataset', 'variance ( data = forest_fire , var1 = DC )'), ('variance of the thalach in heart_disease data', 'variance ( data = heart_disease , var1 = thalach )'), ('sd of the chlorides in wine_quality', 'std ( data = wine_quality , var1 = chlorides )'), ('highest of the loan in bank_marketing df', 'maximum ( data = bank_marketing , var1 = loan )'), ('scatter plot of fixed_acidity and sulphates in wine_quality', 'scatterplot ( data = wine_quality , var1 = fixed_acidity , var2 = sulphates )'), ('amount of radius in breast_cancer df', 'summation ( data = breast_cancer , var1 = radius )'), ('number of info with fbs  >=  -20.44554022297369 ', 'greater_eq ( data = heart_disease , var1 = fbs , val = -20.44554022297369 )'), ('load wine_quality  ', 'load ( data = wine_quality )'), ('number of info  workclass bigger than -19.68217939264258 dataset', 'greater ( data = adult , var1 = workclass , val = -19.68217939264258 )'), ('scatter plot between thalach with cp in heart_disease dataset', 'scatterplot ( data = heart_disease , var1 = thalach , var2 = cp )'), ('std of house_serv in adult data', 'std ( data = adult , var1 = house_serv )'), ('number of entries where alcalinity_of_ash higher than -62.56447394758127 dataset', 'greater ( data = wine , var1 = alcalinity_of_ash , val = -62.5644739 ...
